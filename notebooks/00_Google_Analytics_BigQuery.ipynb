# %% [markdown]
# <a href="https://colab.research.google.com/github/jaime-garvey/web_personalization_portfolio/blob/master/notebooks/00_Google_Analytics_BigQuery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
from google.cloud import bigquery
import pandas as pd

# %%
project_id = '[crafty-chiller-234105]'

# %%
# %%bigquery --project crafty-chiller-234105 df
# SELECT
#     *
# FROM
#     `bigquery-public-data.google_analytics_sample.ga_sessions_20160801`
# Out:
#      visitorId  visitNumber     visitId  visitStartTime      date  \
# 0         None            1  1470117657      1470117657  20160801
# 1         None          151  1470083489      1470083489  20160801
# 2         None            1  1470052694      1470052694  20160801
# 3         None            1  1470061879      1470061879  20160801
# 4         None            1  1470090830      1470090830  20160801
# 5         None            1  1470077855      1470077855  20160801
# 6         None            1  1470084135      1470084135  20160801
# 7         None            1  1470074645      1470074645  20160801
# 8         None            1  1470091947      1470091947  20160801
# 9         None            1  1470077612      1470077612  20160801
# 10        None            1  1470051070      1470051070  20160801
# 11        None            1  1470084347      1470084347  20160801
# 12        None            1  1470043385      1470043385  20160801
# ...

# %%
client = bigquery.Client(project=project_id)

# %%
df.to_csv('ga_sample.csv')

# %%
from google.colab import files

# %%
files.download('ga_sample.csv')
